# %%
from datetime import datetime
import matplotlib.dates as mdates
import pandas as pd
import matplotlib.pyplot as plt
import geopandas
import seaborn as sns
import numpy as np
from matplotlib.pyplot import text
from matplotlib.pyplot import figure

# %%
# read csv files as df
import os

well_event_df = pd.read_csv(os.path.join('..', '..', 'data','well_event_data', 'midland_county_wellevents.csv'))

flaring_pad_df = pd.read_csv(os.path.join('..', '..', 'data','flaring_data', 'wellpads_with_flaring_midland.csv'))
# convert df to GeoDataFrame with longitude and latitude of pads

df_new_1 = geopandas.GeoDataFrame(
    well_event_df, geometry=geopandas.points_from_xy(well_event_df.longitude_pad, well_event_df.latitude_pad))
        
df_new_2 = geopandas.GeoDataFrame(
    flaring_pad_df, geometry=geopandas.points_from_xy(flaring_pad_df.longitude_pad, flaring_pad_df.latitude_pad))

# %%
# spatial join with the nearst longitude and latitude of pads, based on 44 pads in wellpads_with_flaring_midland.csv
df_new_reverse = geopandas.sjoin_nearest(df_new_1,df_new_2,how = 'right')

# %% [markdown]
# <div class="alert alert-block alert-info">Using pd.concat instead of append</div>

# %%
#  parse time series dat
df_nm_flaring2 = pd.DataFrame()

for idx, row in df_new_reverse.iterrows():
    
    # Convert strings to objects
    #ts_mw = eval(row['ts_flaring_power_MW'])
    ts_gj = eval(row['ts_flaring_energy_daily_GJ'])
    
    # Loop through each of the events
    for idx, t in enumerate(ts_gj):
        
        # Parse time
        tmid = datetime.strptime(t['time'], '%Y-%m-%d %H:%M:%S')
        if t['value'] > 0:
            new_row = {
                #  getting all the needed columns with ts_flaring_energy_daily_GJ
              'wellpads_id':row.wellpads_id,
                'well_id':row.id_left,
                'tst_first_detection_date':row.tst_first_detection_date,
                'tst_permit_date':row.tst_permit_date,
                'tst_spud_date':row.tst_spud_date,
                'tst_regulator_completion_date':row.tst_regulator_completion_date,
                'tst_fracfocus_jobstart_date':row.tst_fracfocus_jobstart_date,
                'tst_fracfocus_jobend_date':row.tst_fracfocus_jobend_date,
              'ts_flaring_energy_daily_GJ':ts_gj[idx]['value'],
              #'flaring_power_MW':t['value'],
              'year':int(tmid.year),
              'month':int(tmid.month),
                'day':int(tmid.day)
            }
            
             
            df_nm_flaring2 = pd.concat([df_nm_flaring2, pd.DataFrame.from_dict([new_row])], ignore_index=True)

# %%
#  parse time series dat
df_nm_flaring = pd.DataFrame()

for idx, row in df_new_reverse.iterrows():
    
    # Convert strings to objects
    ts_mw = eval(row['ts_flaring_power_MW'])
    #ts_gj = eval(row['ts_flaring_energy_daily_GJ'])
    
    # Loop through each of the events
    for idx, t in enumerate(ts_mw):
        
        # Parse time
        tmid = datetime.strptime(t['time'], '%Y-%m-%d %H:%M:%S')
        if t['value'] > 0:
            new_row = {
                # getting all the needed columns with ts_flaring_power_MW
              'wellpads_id':row.wellpads_id,
               'well_id':row.id_left, 
                'tst_first_detection_date':row.tst_first_detection_date,
                'tst_permit_date':row.tst_permit_date,
                'tst_spud_date':row.tst_spud_date,
                'tst_regulator_completion_date':row.tst_regulator_completion_date,
                'tst_fracfocus_jobstart_date':row.tst_fracfocus_jobstart_date,
                'tst_fracfocus_jobend_date':row.tst_fracfocus_jobend_date,
              'ts_flaring_power_MW':ts_mw[idx]['value'],
              #'flaring_power_MW':t['value'],
              'year':int(tmid.year),
              'month':int(tmid.month),
                'day':int(tmid.day)
                
            }
            df_nm_flaring = pd.concat([df_nm_flaring,pd.DataFrame.from_dict([new_row])], ignore_index=True)

# %%
# inner join the 2 df to get a df with both ts_flaring_power_MW and ts_flaring_energy_daily_GJ

df_nm_flaring_new = pd.merge(df_nm_flaring2,df_nm_flaring, how ='inner',on = ['wellpads_id','year','month','day','tst_first_detection_date',
                                                                              'tst_permit_date','tst_spud_date','tst_regulator_completion_date',
                                                                              'tst_fracfocus_jobstart_date','tst_fracfocus_jobend_date'])
#df_nm_flaring_new = pd.merge(df_nm_flaring2,df_nm_flaring, how ='inner',on = ['wellpads_id','year','month','day','tst_first_detection_date'])

# %%
# format the datetime by combining year, month, and day
df_nm_flaring_new['Date'] = pd.to_datetime(df_nm_flaring_new[['year','month','day']])

# %%
# to make sure all the datetime are set as date only, without time 
df_nm_flaring_new['tst_first_detection_date'] = pd.to_datetime(df_nm_flaring_new['tst_first_detection_date']).dt.date
df_nm_flaring_new['tst_permit_date'] = pd.to_datetime(df_nm_flaring_new['tst_permit_date']).dt.date
df_nm_flaring_new['tst_regulator_completion_date'] = pd.to_datetime(df_nm_flaring_new['tst_regulator_completion_date']).dt.date
df_nm_flaring_new['tst_fracfocus_jobstart_date'] = pd.to_datetime(df_nm_flaring_new['tst_fracfocus_jobstart_date']).dt.date
df_nm_flaring_new['tst_fracfocus_jobend_date'] = pd.to_datetime(df_nm_flaring_new['tst_fracfocus_jobend_date']).dt.date
df_nm_flaring_new['tst_spud_date'] = pd.to_datetime(df_nm_flaring_new['tst_spud_date']).dt.date

# %% [markdown]
# <div class="alert alert-block alert-info">Added some filters to only keep rows where reg events and flaring data occurs after a pad first detection data</div>

# %%
df_cal = df_nm_flaring_new.copy()
df_cal = df_cal.drop(columns = ['year','month','day','well_id_y'])
df_cal['Date'] = pd.to_datetime(df_cal['Date']).dt.date

#clean up the dataset using some rules

df_cal_filtered = df_cal.copy()

# Keep rows where first_detection is prior to spud date
df_cal_filtered = df_cal_filtered.loc[df_cal['tst_first_detection_date'] <= df_cal['tst_spud_date']]

# Keep rows where flaring data is after first_detection date
df_cal_filtered = df_cal_filtered.loc[df_cal['tst_first_detection_date'] <= df_cal['Date']]


df_cal = df_cal_filtered # df_cal is now the filtered dataframe

# %%
# getting the date diff value here
df_cal['diff_first_detection_flare'] = (df_cal['Date']-df_cal['tst_first_detection_date'] ).dt.days
df_cal['diff_permit_flare'] = (df_cal['Date'] - df_cal['tst_permit_date']).dt.days
df_cal['diff_spud_flare'] = (df_cal['Date'] - df_cal['tst_spud_date'] ).dt.days
df_cal['diff_regulator_completion_flare'] = ( df_cal['Date'] - df_cal['tst_regulator_completion_date'] ).dt.days
df_cal['diff_fracfocus_jobstart_flare'] = ( df_cal['Date'] - df_cal['tst_fracfocus_jobstart_date'] ).dt.days
df_cal['diff_fracfocus_jobend_flare'] = ( df_cal['Date']- df_cal['tst_fracfocus_jobend_date'] ).dt.days

# %%
df_cal_result = df_cal.drop(columns = ['tst_first_detection_date','tst_permit_date','tst_spud_date','tst_regulator_completion_date','tst_fracfocus_jobstart_date','tst_fracfocus_jobend_date','Date'])
df_cal_result
# Out:
#       wellpads_id  well_id_x  ts_flaring_energy_daily_GJ  ts_flaring_power_MW  \
# 71         741130     137407                  141.537356             0.876987
# 72         741130     137407                  365.895068             5.416762
# 73         741130     137407                   69.082917             0.734272
# 74         741130     137407                   47.533255             0.724701
# 75         741130     137407                   48.080743             0.737382
# ...           ...        ...                         ...                  ...
# 1369       738161     136141                   72.303605             1.005193
# 1370       738161     136141                   77.821757             1.201260
# 1371       738161     136141                   58.373001             0.894694
# 1372       738161     136141                   89.125189             1.385485
# 1373       738161     136141                   39.028640             0.597342
#
# ...

# %%
#getting the agg result by mean and group by well pad id
df_cal_result_agg_by_wellid  = pd.DataFrame()
df_cal_result_agg_by_wellid['avg_diff_first_detection_flare'] =  df_cal_result.groupby(['well_id_x'])['diff_first_detection_flare'].agg('mean')
df_cal_result_agg_by_wellid['avg_diff_permit_flare'] =  df_cal_result.groupby(['well_id_x'])['diff_permit_flare'].agg('mean')
df_cal_result_agg_by_wellid['avg_diff_spud_flare'] =  df_cal_result.groupby(['well_id_x'])['diff_spud_flare'].agg('mean')
df_cal_result_agg_by_wellid['avg_diff_regulator_completion_flare'] =  df_cal_result.groupby(['well_id_x'])['diff_regulator_completion_flare'].agg('mean')
df_cal_result_agg_by_wellid['avg_diff_fracfocus_jobstart_flare'] =  df_cal_result.groupby(['well_id_x'])['diff_fracfocus_jobstart_flare'].agg('mean')
df_cal_result_agg_by_wellid['avg_diff_fracfocus_jobend_flare'] =  df_cal_result.groupby(['well_id_x'])['diff_fracfocus_jobend_flare'].agg('mean')
df_cal_result_agg_by_wellid
# Out:
#            avg_diff_first_detection_flare  avg_diff_permit_flare  \
# well_id_x
# 135489                             384.00                 705.00
# 135490                             384.00                 705.00
# 135491                             384.00                 705.00
# 135787                             492.80                 579.80
# 136050                             163.25                 207.25
# ...                                   ...                    ...
# 137780                             186.00                 187.00
# 137781                             186.00                 187.00
# 137782                             186.00                 187.00
# 137809                             186.00                 167.00
# 138444                             219.00               -1013.00
#
#            avg_diff_spud_flare  avg_diff_regulator_completion_flare  \
# well_id_x
# 135489                  296.00                               155.00
# ...

# %%
# plot bar chart and see if there is a relation
avg_diff_first_detection_flare = df_cal_result_agg_by_wellid['avg_diff_first_detection_flare']
avg_diff_permit_flare = df_cal_result_agg_by_wellid['avg_diff_permit_flare']
avg_diff_spud_flare = df_cal_result_agg_by_wellid['avg_diff_spud_flare']
avg_diff_regulator_completion_flare = df_cal_result_agg_by_wellid['avg_diff_regulator_completion_flare']
avg_diff_fracfocus_jobstart_flare = df_cal_result_agg_by_wellid['avg_diff_fracfocus_jobstart_flare']
avg_diff_fracfocus_jobend_flare = df_cal_result_agg_by_wellid['avg_diff_fracfocus_jobend_flare']

 
X = df_cal_result_agg_by_wellid.index

  
X_axis = np.arange(len(X))

fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()

ax.bar(X_axis-1, avg_diff_first_detection_flare, 0.4, label = 'avg_diff_first_detection_flare')
ax.bar(X_axis-0.6, avg_diff_permit_flare, 0.4, label = 'avg_diff_permit_flare')
ax.bar(X_axis-0.2, avg_diff_spud_flare, 0.4, label = 'avg_diff_spud_flare')
ax.bar(X_axis+0.2, avg_diff_regulator_completion_flare, 0.4, label = 'avg_diff_regulator_completion_flare')
ax.bar(X_axis+0.6, avg_diff_fracfocus_jobstart_flare, 0.4, label = 'avg_diff_fracfocus_jobstart_flare')
ax.bar(X_axis+1, avg_diff_fracfocus_jobend_flare, 0.4, label = 'avg_diff_fracfocus_jobend_flare')
  
ax.set_xticks(X_axis, X)
ax.set_xlabel("Groups")
ax.set_ylabel("Number of Days")
ax.set_title("Flare vs markers date")
ax.legend()
plt.show()

# %%
# plot bar chart and see if there is a relation

fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()
y = [df_cal_result['diff_first_detection_flare'].mean(),df_cal_result['diff_permit_flare'].mean(),df_cal_result['diff_spud_flare'].mean(),
    df_cal_result['diff_regulator_completion_flare'].mean(),df_cal_result['diff_fracfocus_jobstart_flare'].mean(),df_cal_result['diff_fracfocus_jobend_flare'].mean()]
  

x = ['detection', 'permit', 'spud', 'regulator_completion', 'fracfocus_jobstart', 'fracfocus_jobend']

x_loop = [i for i, _ in enumerate(x)]

ax.bar(x_loop, y)


ax.set_xticks(x_loop, x)
ax.set_xlabel("Types")
ax.set_ylabel("Number of Days")
ax.set_title("Flare vs markers date")
plt.show()

# %%
df_cal_result.describe()
# Out:
#          wellpads_id      well_id_x  ts_flaring_energy_daily_GJ  \
# count     839.000000     839.000000                  839.000000
# mean   659877.313468  136383.514899                  194.509321
# std    209471.330374     396.354620                  186.677082
# min    107009.000000  135489.000000                    9.891916
# 25%    741128.000000  136257.000000                   57.477802
# 50%    741128.000000  136259.000000                  123.333591
# 75%    741128.000000  136274.000000                  275.399068
# max    751003.000000  138444.000000                 1118.150086
#
#        ts_flaring_power_MW  diff_first_detection_flare  diff_permit_flare  \
# count           839.000000                  839.000000         839.000000
# mean              2.592777                  466.848629         380.020262
# std               2.725414                  228.544543         225.369335
# min               0.152415                   31.000000       -1037.000000
# ...

# %%
df_cal_result_agg_by_wellpad =  df_cal_result.groupby('wellpads_id').describe()
df_cal_result_agg_by_wellpad
# Out:
#             well_id_x                                                  \
#                 count           mean         std       min        25%
# wellpads_id
# 107009            5.0  138444.000000    0.000000  138444.0  138444.00
# 107506           60.0  136094.000000    0.823387  136093.0  136093.00
# 111866            6.0  136167.500000    0.547723  136167.0  136167.00
# 113551           30.0  135787.000000    0.000000  135787.0  135787.00
# 269878            9.0  136736.000000    0.866025  136735.0  136735.00
# 723150           34.0  136345.000000   35.526345  136310.0  136310.00
# 729624            6.0  135806.666667  347.381443  135489.0  135490.25
# 733521            6.0  136850.500000    2.073644  136848.0  136849.25
# 736796           10.0  137518.000000    2.748737  137514.0  137517.00
# 738157            8.0  136050.000000    0.000000  136050.0  136050.00
# 738161           26.0  136139.500000    1.529706  136138.0  136138.00
# ...

# %%
# multiple line plots

fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()

ax.set_title('Avg Wellpads Date Difference')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_first_detection_flare']['mean'],label='diff_first_detection_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_permit_flare']['mean'],label='diff_permit_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_spud_flare']['mean'],label='diff_spud_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_regulator_completion_flare']['mean'],label='diff_regulator_completion_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_fracfocus_jobstart_flare']['mean'],label='diff_fracfocus_jobstart_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_fracfocus_jobend_flare']['mean'],label='diff_fracfocus_jobend_flare')

#plt.plot( df_cal_result_agg_by_wellpad['diff_first_detection_flare']['mean'])
ax.legend()

# show graph
plt.show()

# %%
# multiple line plots
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()

ax.set_title('Std Wellpads Date Difference')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_first_detection_flare']['std'],label='diff_first_detection_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_permit_flare']['std'],label='diff_permit_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_spud_flare']['std'],label='diff_spud_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_regulator_completion_flare']['std'],label='diff_regulator_completion_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_fracfocus_jobstart_flare']['std'],label='diff_fracfocus_jobstart_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_fracfocus_jobend_flare']['std'],label='diff_fracfocus_jobend_flare')

#plt.plot( df_cal_result_agg_by_wellpad['diff_first_detection_flare']['mean'])
ax.legend()

# show graph
plt.show()

# %%
# multiple line plots
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()

ax.set_title('Range Wellpads Date Difference')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_first_detection_flare']['max']-df_cal_result_agg_by_wellpad['diff_first_detection_flare']['min'].abs(),label='diff_first_detection_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_permit_flare']['max']-df_cal_result_agg_by_wellpad['diff_permit_flare']['min'].abs(),label='diff_permit_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_spud_flare']['max']-df_cal_result_agg_by_wellpad['diff_spud_flare']['min'].abs(),label='diff_spud_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_regulator_completion_flare']['max']-df_cal_result_agg_by_wellpad['diff_regulator_completion_flare']['min'].abs(),label='diff_regulator_completion_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_fracfocus_jobstart_flare']['max']-df_cal_result_agg_by_wellpad['diff_fracfocus_jobstart_flare']['min'].abs(),label='diff_fracfocus_jobstart_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad['diff_fracfocus_jobend_flare']['max']-df_cal_result_agg_by_wellpad['diff_fracfocus_jobend_flare']['min'].abs(),label='diff_fracfocus_jobend_flare')

#plt.plot( df_cal_result_agg_by_wellpad['diff_first_detection_flare']['mean'])
ax.legend()

# show graph
plt.show()

# %%
df_cal_result_agg_by_wellpad_median =  df_cal_result.groupby('wellpads_id').agg('median')
# multiple line plots

fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()

ax.set_title('Median Wellpads Date Difference')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'],label='diff_first_detection_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad_median['diff_permit_flare'],label='diff_permit_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad_median['diff_spud_flare'],label='diff_spud_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad_median['diff_regulator_completion_flare'],label='diff_regulator_completion_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad_median['diff_fracfocus_jobstart_flare'],label='diff_fracfocus_jobstart_flare')
ax.plot(np.arange(len(df_cal_result_agg_by_wellpad_median['diff_first_detection_flare'].index)), df_cal_result_agg_by_wellpad_median['diff_fracfocus_jobend_flare'],label='diff_fracfocus_jobend_flare')

#plt.plot( df_cal_result_agg_by_wellpad['diff_first_detection_flare']['mean'])
ax.legend()

# show graph
plt.show()

# %%
df_cal_result.select_dtypes(exclude=['object']).hist(figsize= (20, 30))
plt.subplots_adjust(wspace=0.3, hspace=0.5)

# %%
# create correlation table
corr_tb = df_cal_result.corr()

# create mask
mask = np.zeros_like(corr_tb, dtype=np.bool)
mask[np.triu_indices_from(mask, k=0)] = True

# generate colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# initialise figure
f, ax = plt.subplots(figsize=(11, 9))

# draw heatmap
sns.heatmap(corr_tb, mask=mask, cmap=cmap, center=0, 
            annot=True, square=True, linewidths=.5) 

# show figure
plt.show()
# Out:
# C:\Users\Shihao Zhou\AppData\Local\Temp\ipykernel_32280\2848191490.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr_tb, dtype=np.bool)

# %%
df_cal.to_csv('filtered_data.csv')

# %%
from datetime import datetime
import matplotlib.dates as mdates
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import glob

# %%
path = r'D:\UCL\Term3\tbx-flaring-shihao\src\notebooks\WIP_data\RNN_v2' 
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
csv_files[1]
# Out:
# 'D:\\UCL\\Term3\\tbx-flaring-shihao\\src\\notebooks\\WIP_data\\RNN_v2\\1.csv'

# %%
from tqdm.notebook import tqdm
for i in tqdm(range(54134)):
    df = pd.read_csv(csv_files[i],usecols=range(1,40))
    df= df.drop_duplicates()
    df.to_csv(str(i)+'.csv')
# Out:
#   0%|          | 0/54134 [00:00<?, ?it/s]

# %%
df = pd.read_csv(r'D:\UCL\Term3\tbx-flaring-shihao\src\notebooks\WIP_data\RNN_v2\0.csv',usecols=range(1,40))

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#      t_n  company_type    area_m2  wells  wellpad_vintage_year  flares_n_acc  \
# 0      1             0  35732.246      1                  2017             0
# 1      2             0  35732.246      1                  2017             0
# 2      3             0  35732.246      1                  2017             0
# 3      4             0  35732.246      1                  2017             0
# 4      5             0  35732.246      1                  2017             0
# ..   ...           ...        ...    ...                   ...           ...
# 164  165             0  35732.246      1                  2017             0
# 165  166             0  35732.246      1                  2017             0
# 166  167             0  35732.246      1                  2017             0
# 167  168             0  35732.246      1                  2017             0
# 168  169             0  35732.246      1                  2017             0
#
# ...
